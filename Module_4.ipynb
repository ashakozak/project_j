# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File to Load
international_port = Path("Resources/internationalport_country.csv")
local_city = Path("Resources/localcity_australia.csv")

# Read airline Data File and store into Pandas DataFrames
international_port_df = pd.read_csv(international_port)
local_city_df = pd.read_csv(local_city)

# %%
# Display the data table for international_port
international_port_df
# Out:
#         Month                Airline   Port_Country  Passengers_In  \
# 0      Jan-85          Air Caledonie  New Caledonia            725
# 1      Jan-85              Air China          China           1311
# 2      Jan-85              Air India          India           1423
# 3      Jan-85              Air India      Singapore            501
# 4      Jan-85              Air Nauru          Nauru            161
# ...       ...                    ...            ...            ...
# 44822  Sep-22  United Parcel Service            USA              0
# 44823  Sep-22       Vietnam Airlines        Vietnam          12957
# 44824  Sep-22       Virgin Australia           Fiji           9164
# 44825  Sep-22       Virgin Australia      Indonesia          15665
# 44826  Sep-22        Xiamen Airlines          China           3456
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0                    0.368             0.000             474
# ...

# %%
# Get data after 2000 from international_port_df
international_year = international_port_df.loc[international_port_df["Year"]>=2000]
international_year
# Out:
#         Month                Airline   Port_Country  Passengers_In  \
# 17253  Jan-00  Aerolineas Argentinas      Argentina           1725
# 17254  Jan-00  Aerolineas Argentinas    New Zealand            606
# 17255  Jan-00          Air Caledonie  New Caledonia           4086
# 17256  Jan-00              Air China          China           5121
# 17257  Jan-00          Air Mauritius      Mauritius           1454
# ...       ...                    ...            ...            ...
# 44822  Sep-22  United Parcel Service            USA              0
# 44823  Sep-22       Vietnam Airlines        Vietnam          12957
# 44824  Sep-22       Virgin Australia           Fiji           9164
# 44825  Sep-22       Virgin Australia      Indonesia          15665
# 44826  Sep-22        Xiamen Airlines          China           3456
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 17253                1.801             0.733            1667
# ...

# %%
# Drop rows with zero passengers
international_year_dropped = international_year.drop(international_year[international_year["Passengers_In"] ==0].index)
international_year_dropped
# Out:
#         Month                Airline   Port_Country  Passengers_In  \
# 17253  Jan-00  Aerolineas Argentinas      Argentina           1725
# 17254  Jan-00  Aerolineas Argentinas    New Zealand            606
# 17255  Jan-00          Air Caledonie  New Caledonia           4086
# 17256  Jan-00              Air China          China           5121
# 17257  Jan-00          Air Mauritius      Mauritius           1454
# ...       ...                    ...            ...            ...
# 44819  Sep-22        United Airlines            USA          18945
# 44823  Sep-22       Vietnam Airlines        Vietnam          12957
# 44824  Sep-22       Virgin Australia           Fiji           9164
# 44825  Sep-22       Virgin Australia      Indonesia          15665
# 44826  Sep-22        Xiamen Airlines          China           3456
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 17253                1.801             0.733            1667
# ...

# %%
# Replace month_num with months
months_dict = {1: "January", 2: "February", 3: "March", 4: "April", 5: "May", 6: "June", 7: "July", 8: "August",
               9: "September", 10: "October", 11: "November", 12: "December"}
international_year_dropped["Month_num"] = international_year_dropped["Month_num"].replace(months_dict)
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September",
         "October", "November", "December"]
international_year_dropped["Month_num"] = pd.Categorical(international_year_dropped["Month_num"], categories=months, ordered=True)

# %%
# Identify the travel months
months_travel = international_year_dropped["Month_num"].unique().tolist()
months_travel
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
# Identify busiest season by determining total number of passengers from international_year_dropped - groupby month
international_monthly_passenger = international_year_dropped.groupby("Month_num")[["Passengers_In"]].mean()
international_monthly_passenger
# Out:
#            Passengers_In
# Month_num
# January     15675.479853
# February    12683.590717
# March       11880.053543
# April       11962.383822
# May         10700.133588
# June        11049.486764
# July        14822.493181
# August      12663.570411
# September   12989.110990
# October     14560.020443
# November    12552.191393
# December    13592.944629

# %%
# Pyplot busiest season from 2000 - 2022

plt.figure(figsize=(9,7))
plt.bar(international_monthly_passenger.index,international_monthly_passenger["Passengers_In"])
plt.xlabel("Months")
plt.xticks(rotation=45)
plt.ylabel("Average Number of Travellers")
plt.title("Busiest Season of International Travellers to Australia 2000 - 2022")
plt.grid()
plt.savefig('busiest_season.png')
plt.tight_layout

plt.show()

# %%
# Identify travel trend of busiest season from 2000 - 2022
international_monthly_pax_yr = international_year_dropped.groupby(["Year", "Month_num"])[["Passengers_In"]].mean()
international_monthly_pax_yr

# Reset index
international_monthly_pax_yr = international_monthly_pax_yr.reset_index()
international_monthly_pax_yr
# Out:
#      Year  Month_num  Passengers_In
# 0    2000    January    7653.478723
# 1    2000   February    7087.861702
# 2    2000      March    6668.000000
# 3    2000      April    7210.591398
# 4    2000        May    6015.526882
# ..    ...        ...            ...
# 271  2022     August   14653.842857
# 272  2022  September   14970.788732
# 273  2022    October            NaN
# 274  2022   November            NaN
# 275  2022   December            NaN
#
# [276 rows x 3 columns]

# %%
# Create dataframe for passengers per month from 2000 - 2022
january_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "January",
                                              ["Year", "Month_num", "Passengers_In"]]
february_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "February",
                                              ["Year", "Month_num", "Passengers_In"]]
march_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "March",
                                              ["Year", "Month_num", "Passengers_In"]]
april_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "April",
                                              ["Year", "Month_num", "Passengers_In"]]
may_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "May",
                                              ["Year", "Month_num", "Passengers_In"]]
june_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "June",
                                              ["Year", "Month_num", "Passengers_In"]]
july_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "July",
                                              ["Year", "Month_num", "Passengers_In"]]
august_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "August",
                                              ["Year", "Month_num", "Passengers_In"]]
september_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "September",
                                              ["Year", "Month_num", "Passengers_In"]]
october_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "October",
                                              ["Year", "Month_num", "Passengers_In"]]
november_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "November",
                                              ["Year", "Month_num", "Passengers_In"]]
december_pax = international_monthly_pax_yr.loc[international_monthly_pax_yr["Month_num"] == "December",
                                              ["Year", "Month_num", "Passengers_In"]]

# %%
# Pyplot travel trend of busiest season from 2000 - 2022

plt.figure(figsize=(10,7))
plt.plot(january_pax["Year"], january_pax["Passengers_In"], label = "January")
plt.plot(february_pax["Year"], february_pax["Passengers_In"], label = "February")
plt.plot(march_pax["Year"], march_pax["Passengers_In"], label = "March")
plt.plot(april_pax["Year"], april_pax["Passengers_In"], label = "April")
plt.plot(may_pax["Year"], may_pax["Passengers_In"], label = "May")
plt.plot(june_pax["Year"], june_pax["Passengers_In"], label = "June")
plt.plot(july_pax["Year"], july_pax["Passengers_In"], label = "July")
plt.plot(august_pax["Year"], august_pax["Passengers_In"], label = "August")
plt.plot(september_pax["Year"], september_pax["Passengers_In"], label = "September")
plt.plot(october_pax["Year"], october_pax["Passengers_In"], label = "October")
plt.plot(november_pax["Year"], november_pax["Passengers_In"], label = "November")
plt.plot(december_pax["Year"], december_pax["Passengers_In"], label = "December")
plt.title("Busiest Season Throughout the Years 2000 - 2022")
plt.xlabel("Years")
plt.ylabel("Average Numbers of Travellers")
plt.grid()
plt.legend(loc="best")
plt.savefig('season_years.png')
plt.tight_layout

plt.show()

# %%
# Work with local data in Australia
# Display the data table for local cities in Australia
local_city_df
# Out:
#         Month      AustralianPort ForeignPort          Country  Passengers_In  \
# 0      Jan-85            Adelaide    Auckland      New Zealand           1513
# 1      Jan-85            Adelaide     Bahrain          Bahrain             12
# 2      Jan-85            Adelaide      Bombay            India              7
# 3      Jan-85            Adelaide   Frankfurt          Germany            115
# 4      Jan-85            Adelaide      London               UK           1567
# ...       ...                 ...         ...              ...            ...
# 84459  Sep-22              Sydney       Tokyo            Japan           9135
# 84460  Sep-22              Sydney   Vancouver           Canada          11790
# 84461  Sep-22              Sydney  Wellington      New Zealand           8329
# 84462  Sep-22              Sydney      Xiamen            China           1328
# 84463  Sep-22  Toowoomba Wellcamp   Hong Kong  Hong Kong (SAR)              0
#
# ...

# %%
# Get data after 2000 from local_city_df
local_city_year = local_city_df.loc[local_city_df["Year"]>=2000]
local_city_year
# Out:
#         Month      AustralianPort   ForeignPort          Country  \
# 39227  Jan-00            Adelaide       Atlanta              USA
# 39228  Jan-00            Adelaide      Auckland      New Zealand
# 39229  Jan-00            Adelaide       Bangkok         Thailand
# 39230  Jan-00            Adelaide        Bombay            India
# 39231  Jan-00            Adelaide  Buenos Aires        Argentina
# ...       ...                 ...           ...              ...
# 84459  Sep-22              Sydney         Tokyo            Japan
# 84460  Sep-22              Sydney     Vancouver           Canada
# 84461  Sep-22              Sydney    Wellington      New Zealand
# 84462  Sep-22              Sydney        Xiamen            China
# 84463  Sep-22  Toowoomba Wellcamp     Hong Kong  Hong Kong (SAR)
#
#        Passengers_In  Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 39227              0                4.049             0.000               0
# ...

# %%
# Drop rows with zero passengers
local_city_year_dropped = local_city_year.drop(local_city_year[local_city_year["Passengers_In"] ==0].index)
local_city_year_dropped
# Out:
#         Month AustralianPort   ForeignPort      Country  Passengers_In  \
# 39228  Jan-00       Adelaide      Auckland  New Zealand             60
# 39229  Jan-00       Adelaide       Bangkok     Thailand              1
# 39230  Jan-00       Adelaide        Bombay        India             29
# 39231  Jan-00       Adelaide  Buenos Aires    Argentina             12
# 39233  Jan-00       Adelaide  Christchurch  New Zealand             18
# ...       ...            ...           ...          ...            ...
# 84458  Sep-22         Sydney        Taipei       Taiwan            925
# 84459  Sep-22         Sydney         Tokyo        Japan           9135
# 84460  Sep-22         Sydney     Vancouver       Canada          11790
# 84461  Sep-22         Sydney    Wellington  New Zealand           8329
# 84462  Sep-22         Sydney        Xiamen        China           1328
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# ...

# %%
# Identify names of local city
local_city_pax = local_city_year_dropped["AustralianPort"].unique().tolist()
local_city_pax
# Out:
# ['Adelaide',
#  'Brisbane',
#  'Cairns',
#  'Darwin',
#  'Gold Coast/Coolangatta',
#  'Melbourne',
#  'Norfolk Island',
#  'Perth',
#  'Sydney',
#  'Broome',
#  'Townsville',
#  'Newcastle',
#  'Canberra',
#  'Christmas Island',
#  'Gold Coast',
#  'Port Hedland',
#  'Sunshine Coast',
#  'Hobart']

# %%
# Clean up local city
local_city_year_dropped ["AustralianPort"] = local_city_year_dropped["AustralianPort"].replace({"Gold Coast/Coolangatta":
                                                                                               "Gold Coast"})

# %%
# Check if it has been cleaned
local_city_pax_cleaned = local_city_year_dropped["AustralianPort"].unique().tolist()
local_city_pax_cleaned
# Out:
# ['Adelaide',
#  'Brisbane',
#  'Cairns',
#  'Darwin',
#  'Gold Coast',
#  'Melbourne',
#  'Norfolk Island',
#  'Perth',
#  'Sydney',
#  'Broome',
#  'Townsville',
#  'Newcastle',
#  'Canberra',
#  'Christmas Island',
#  'Port Hedland',
#  'Sunshine Coast',
#  'Hobart']

# %%
# Replace month_num with months
months_dict = {1: "January", 2: "February", 3: "March", 4: "April", 5: "May", 6: "June", 7: "July", 8: "August",
               9: "September", 10: "October", 11: "November", 12: "December"}
local_city_year_dropped["Month_num"] = local_city_year_dropped["Month_num"].replace(months_dict)
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September",
         "October", "November", "December"]
local_city_year_dropped["Month_num"] = pd.Categorical(local_city_year_dropped["Month_num"], categories=months, ordered=True)

# %%
# Determine number of passengers per local city
local_city_pax = local_city_year_dropped.groupby("AustralianPort")[["Passengers_In"]].mean()
local_city_pax.head(8)
# Out:
#                   Passengers_In
# AustralianPort
# Adelaide            3441.400874
# Brisbane            6004.132873
# Broome               163.625000
# Cairns              2533.522896
# Canberra            1549.000000
# Christmas Island     134.666667
# Darwin              1655.900152
# Gold Coast          4026.824213

# %%
# Pyplot number of passengers per local city

plt.figure(figsize=(9,7))
plt.bar(local_city_pax.index,local_city_pax["Passengers_In"])
plt.xlabel("Australian Port")
plt.xticks(rotation=55)
plt.ylabel("Average Number of Travellers")
plt.title("International Travellers to Australian Cities")
plt.grid()
plt.savefig('busy_localcity.png')
plt.tight_layout

plt.show()

# %%
# Sort data to determine which local city has the most number of passengers
local_city_pax_sorted = local_city_pax.sort_values("Passengers_In", ascending=False)
local_city_pax_sorted.head(12)

#
local_city_pax_sorted = local_city_pax_sorted.reset_index()
local_city_pax_sorted.head(12)
# Out:
#     AustralianPort  Passengers_In
# 0           Sydney    9582.599605
# 1        Melbourne    8289.310948
# 2            Perth    8155.516723
# 3         Brisbane    6004.132873
# 4       Gold Coast    4026.824213
# 5         Adelaide    3441.400874
# 6           Cairns    2533.522896
# 7           Darwin    1655.900152
# 8         Canberra    1549.000000
# 9   Sunshine Coast    1333.414634
# 10      Townsville     955.530303
# 11       Newcastle     702.333333

# %%
# Determine number of passengers per local_city - groupby Australian port and month
local_city_port = local_city_year_dropped.groupby(["AustralianPort", "Month_num"])[["Passengers_In"]].mean()
local_city_port.head(12)

#
local_city_port = local_city_port.reset_index()
local_city_port
# Out:
#     AustralianPort  Month_num  Passengers_In
# 0         Adelaide    January    3892.348571
# 1         Adelaide   February    3102.816092
# 2         Adelaide      March    2815.907514
# 3         Adelaide      April    3246.485915
# 4         Adelaide        May    3010.884058
# ..             ...        ...            ...
# 199     Townsville     August     947.200000
# 200     Townsville  September    1000.833333
# 201     Townsville    October    1027.000000
# 202     Townsville   November     589.500000
# 203     Townsville   December     654.875000
#
# [204 rows x 3 columns]

# %%
# Sort data to determine which local city and season the busiest
local_city_port_sorted = local_city_port.sort_values("Passengers_In", ascending=False)
local_city_port_sorted.head(12)

#
#local_city_port_sorted = local_city_port_sorted.reset_index()
#local_city_port_sorted.head(12)
# Out:
#     AustralianPort  Month_num  Passengers_In
# 180         Sydney    January   11780.916211
# 186         Sydney       July   10806.092715
# 189         Sydney    October   10695.697537
# 191         Sydney   December   10190.049133
# 144          Perth    January   10086.207715
# 108      Melbourne    January    9775.516039
# 181         Sydney   February    9554.059908
# 114      Melbourne       July    9459.713433
# 153          Perth    October    9449.428115
# 188         Sydney  September    9387.325427
# 190         Sydney   November    9364.866732
# 150          Perth       July    9327.331250

# %%
# Create dataframe for passengers per local city 
sydney_pax = local_city_port.loc[local_city_port["AustralianPort"] == "Sydney",
                                              ["AustralianPort", "Month_num", "Passengers_In"]]
melbourne_pax = local_city_port.loc[local_city_port["AustralianPort"] == "Melbourne",
                                              ["AustralianPort", "Month_num", "Passengers_In"]]
perth_pax = local_city_port.loc[local_city_port["AustralianPort"] == "Perth",
                                              ["AustralianPort", "Month_num", "Passengers_In"]]
brisbane_pax = local_city_port.loc[local_city_port["AustralianPort"] == "Brisbane",
                                              ["AustralianPort", "Month_num", "Passengers_In"]]
goldcoast_pax = local_city_port.loc[local_city_port["AustralianPort"] == "Gold Coast",
                                              ["AustralianPort", "Month_num", "Passengers_In"]]

# %%
# Pyplot busiest season per local city

plt.figure(figsize=(10,7))
plt.plot(sydney_pax["Month_num"], sydney_pax["Passengers_In"], label = "Sydney")
plt.plot(melbourne_pax["Month_num"], melbourne_pax["Passengers_In"], label = "Melbourne")
plt.plot(perth_pax["Month_num"], perth_pax["Passengers_In"], label = "Perth")
plt.plot(brisbane_pax["Month_num"], brisbane_pax["Passengers_In"], label = "Brisbane")
plt.plot(goldcoast_pax["Month_num"], goldcoast_pax["Passengers_In"], label = "Gold Coast")
plt.title("Busiest Season of Top Local Australian Cities")
plt.xlabel("Months")
plt.xticks(rotation=45)
plt.ylabel("Average Numbers of Travellers")
plt.grid()
plt.legend(loc="best")
plt.savefig('season_localcity.png')
plt.tight_layout

plt.show()

# %% [markdown]
# ANALYSIS:
#
# The busiest season of international travellers to Australia are during the months of January, July, October and December.
# January - with the Australian Open, and the start of the new school year.
# July - winter, or the good weather to visit the beaches of Sydney and Brisbane.
# October - spring, and Melbourne Cup.
# December - holiday and with overseas returning to celebrate with family.
# These months have consistently been the busiest season throughout the years.
# The most visited Australian Cities are Sydney, Melbourne, Perth and Gold Coast.
# The busiest season of these Australian cities are the months of June, July, October and December.
# The decline of international travellers from 2020 can be significantly attributed to Covid 19, with the closure of international border.
